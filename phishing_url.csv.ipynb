# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('phishing_url_dataset_unique.csv')
df
# Out:
#                                                      url  label   source
# 0                      http://110.37.26.193:54956/bin.sh      1  urlhaus
# 1               https://sentry5.obor1shwron8.ru/4ylkytvt      1  urlhaus
# 2                   https://d6gu.ripple-cask.ru/jid43vpd      1  urlhaus
# 3      http://130.12.180.34/596a96cc7bf9108cd896f33c4...      1  urlhaus
# 4                                 https://bronze.systems      0   tranco
# ...                                                  ...    ...      ...
# 48807            https://zelnip.mo5hnap2sser.ru/b1a0bitj      1  urlhaus
# 48808                             https://ittefaq.com.bd      0   tranco
# 48809                                https://atidevs.com      0   tranco
# 48810         http://45.156.87.115/hiddenbin/boatnet.spc      1  urlhaus
# 48811                       http://175.30.47.193:50511/i      1  urlhaus
#
# [48812 rows x 3 columns]

# %%
df.head()
df.tail()
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48812 entries, 0 to 48811
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     48812 non-null  object
#  1   label   48812 non-null  int64
#  2   source  48812 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 762.8+ KB

# %%
df.describe()
# Out:
#               label
# count  48812.000000
# mean       0.500000
# std        0.500005
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# url       0
# label     0
# source    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat_cols = df.select_dtypes(include= ['object']).columns.tolist()
num_cols = df.select_dtypes(include = ['int64']).columns.tolist()

print("Categorical columns:", cat_cols)
print("Numerical columns:", num_cols)
# Out:
# Categorical columns: ['url', 'source']
# Numerical columns: ['label']

# %%
for col in cat_cols:
    print(f"\nValue counts for '{col}':")
    print(df[col].value_counts())
# Out:
# Value counts for 'url':
# url
# http://110.37.26.193:54956/bin.sh                                                1
# https://xsw.tw                                                                   1
# https://github.com/PSHNIM/AntiAutoFish/releases/download/v1.0/Application.zip    1
# https://grserver.gr                                                              1
# https://reelshort.com                                                            1
#                                                                                 ..
# https://mobalytics.gg                                                            1
# https://dogdrip.net                                                              1
# http://110.37.13.91:41035/bin.sh                                                 1
# https://stores.jp                                                                1
# http://175.30.47.193:50511/i                                                     1
# Name: count, Length: 48812, dtype: int64
#
# Value counts for 'source':
# source
# tranco       24406
# urlhaus      24106
# openphish      300
# Name: count, dtype: int64

# %%
df.groupby('source')['label'].count().plot(kind='bar')
plt.title("Source vs Phishing Rate")
plt.xlabel("Source")
plt.ylabel("Label ")
plt.show()
